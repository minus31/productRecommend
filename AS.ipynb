# %%
from main import Descriptor

# %%
args = {}

args["epoch"]              = 1000
args["batch_size"]         = 64
args["num_classes"]        = 600
args["input_shape"]        = (256, 256, 3)
args["sbow_shape"]         = (128,)
args["train"]              = False
args["updateDB"]           = False
args["eval"]               = False
args["model_path"]         = "./checkpoint/finish"
args["dataset_path"]       = "./data/images/"
args["checkpoint_path"]    = "./checkpoint/"
args["checkpoint_inteval"] = 10 
args["k"]                  = 21

# %%
from collections import namedtuple

args_ = namedtuple("Arguments", args.keys())(*args.values())
args_
# Out:
# Arguments(epoch=1000, batch_size=64, num_classes=600, input_shape=(256, 256, 3), sbow_shape=(128,), train=False, updateDB=False, eval=False, model_path='./checkpoint/finish', dataset_path='./data/images/', checkpoint_path='./checkpoint/', checkpoint_inteval=10, k=21)

# %%
descriptor = Descriptor(args_)
# Out:
# WARNING:tensorflow:From /Users/MAC/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /Users/MAC/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
descriptor.evaluate("/Users/MAC/Desktop/dev/productRecommend/checkpoint/40")
# Out:
# Found 300 images belonging to 1 classes.
# 10/10 [==============================] - 57s 6s/step
# Found 3530 images belonging to 1 classes.
# 111/111 [==============================] - 739s 7s/step
# (0.008230910901963534,
#  {'0_snap.png': 0.08333333333333333,
#   '100_snap.png': 0,
#   '101_snap.png': 0,
#   '102_snap.png': 0,
#   '103_snap.png': 0,
#   '104_snap.png': 0.14285714285714285,
#   '105_snap.png': 0,
#   '106_snap.png': 0,
#   '107_snap.png': 0,
#   '108_snap.png': 0,
#   '109_snap.png': 0,
#   '10_snap.png': 0,
#   '110_snap.png': 0,
#   '111_snap.png': 0.34090909090909094,
#   '112_snap.png': 0,
#   '113_snap.png': 0,
#   '114_snap.png': 0,
#   '115_snap.png': 0,
#   '116_snap.png': 0,
#   '117_snap.png': 0,
#   '118_snap.png': 0,
#   '119_snap.png': 0,
#   '11_snap.png': 0,
#   '120_snap.png': 0,
#   '121_snap.png': 0,
#   '122_snap.png': 0,
#   '123_snap.png': 0,
#   '124_snap.png': 0.047619047619047616,
#   '125_snap.png': 0,
#   '126_snap.png': 0,
# ...
